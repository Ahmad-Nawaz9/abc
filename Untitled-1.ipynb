# %%
pip install seaborn
# Out:
# ...
#   Using cached pandas-1.4.1-cp39-cp39-win_amd64.whl (10.5 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'C:\Users\Masfufa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\Masfufa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\Masfufa\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\Masfufa\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn as sns
import numpy as np 
import pandas as pd

# %%
kashti = sns.load_dataset("titanic")
# ks1 = kashti
# ks2 = kashti

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
ks1 = kashti.drop(['alive','embark_town','deck'],axis=1)
ks1.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male  alone
# 0    man        True  False
# 1  woman       False  False
# 2  woman       False   True
# 3  woman       False  False
# ...

# %%
mean = ks1['age'].mean()
print(mean)
ks1['age'] = ks1['age'].replace(np.nan , mean)

ks1['Age_in_days'] = ks1['age']*365
# Out:
# 29.69911764705882

# %%
ks1=ks1.dropna()
ks1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  alone  Age_in_days
# 0    man        True  False       8030.0
# 1  woman       False  False      13870.0
# 2  woman       False   True       9490.0
# 3  woman       False  False      12775.0
# 4    man        True   True      12775.0

# %%
#6 Append the demmies 
genders = {"male": 0, "female": 1}
data = [ks1]

for ks1 in data:
    ks1['sex'] = ks1['sex'].map(genders)

# %%
ks1.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    0  22.0      1      0   7.2500        S  Third    man
# 1         1       1    1  38.0      1      0  71.2833        C  First  woman
# 2         1       3    1  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    1  35.0      1      0  53.1000        S  First  woman
# 4         0       3    0  35.0      0      0   8.0500        S  Third    man
#
#    adult_male  alone  Age_in_days
# 0        True  False       8030.0
# 1       False  False      13870.0
# 2       False   True       9490.0
# 3       False  False      12775.0
# 4        True   True      12775.0

# %%
ks5 = ks1.copy()

# %%
ks5.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    0  22.0      1      0   7.2500        S  Third    man
# 1         1       1    1  38.0      1      0  71.2833        C  First  woman
# 2         1       3    1  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    1  35.0      1      0  53.1000        S  First  woman
# 4         0       3    0  35.0      0      0   8.0500        S  Third    man
#
#    adult_male  alone  Age_in_days
# 0        True  False       8030.0
# 1       False  False      13870.0
# 2       False   True       9490.0
# 3       False  False      12775.0
# 4        True   True      12775.0

# %%
x = {"False": 0, "Ture": 1}
data =[ks5]
for ks5 in data:
    ks5['adult_male'] = ks5['adult_male'].map(x)

# %%
ks1['alone'] = pd.get_dummies('alone')

# %%
ks1.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    0  22.0      1      0   7.2500        S  Third    man
# 1         1       1    1  38.0      1      0  71.2833        C  First  woman
# 2         1       3    1  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    1  35.0      1      0  53.1000        S  First  woman
# 4         0       3    0  35.0      0      0   8.0500        S  Third    man
#
#    adult_male  alone  Age_in_days
# 0        True    1.0       8030.0
# 1       False    NaN      13870.0
# 2       False    NaN       9490.0
# 3       False    NaN      12775.0
# 4        True    NaN      12775.0

# %%
ks5.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male     891
# alone            0
# Age_in_days      0
# dtype: int64

# %%
a = [1,2,3,'ahmad',False]

# %%
a.reverse()

# %%
s =a.count(a)
